# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ## This script contains the following points:
#
# ### 01. Importing Libraries
# ### 02. Importing Data
# ### 03. Checking Dataframes
# ### 04. Finding the Aggregated Mean
# ### 05. Creating a Loyalty Flag
# ### 06. Creating a Spending Flag
# ### 07. Creating a Frequency Flag
# ### 08. Exporting Data

# %% [markdown]
# ## 01. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing Data

# %%
# Set project folder as a string
path = r'/Users/matthewjones/Documents/CareerFoundry/Data Immersion/Achievement 4/04-2024 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_NewVariables.pkl'))

# %% [markdown]
# ## 03. Checking Dataframes

# %%
# Check the shape and output of the dataframe
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
# 5   2398795        1             2                  3                  7
# 6   2398795        1             2                  3                  7
# 7   2398795        1             2                  3                  7
# 8   2398795        1             2                  3                  7
# 9   2398795        1             2                  3                  7
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
# 5                    15.0         False         196                  1
# 6                    15.0         False       10258                  2
# 7                    15.0         False       12427                  3
# 8                    15.0         False       13176                  4
# 9                    15.0         False       26088                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# 1          0  Organic Unsweetened Vanilla Almond Milk        91
# 2          0                      Original Beef Jerky        23
# 3          0               Aged White Cheddar Popcorn        23
# 4          0         XL Pick-A-Size Paper Towel Rolls        54
# 5          1                                     Soda        77
# 6          0                               Pistachios       117
# 7          1                      Original Beef Jerky        23
# 8          0                   Bag of Organic Bananas        24
# 9          1               Aged White Cheddar Popcorn        23
#
#    department_id  prices        price_label     busiest_day    busiest_days  \
# 0              7     9.0  Mid-Range Product  Regularly busy  Regularly busy
# 1             16    12.5  Mid-Range Product  Regularly busy  Regularly busy
# 2             19     4.4  Low-Range Product  Regularly busy  Regularly busy
# 3             19     4.7  Low-Range Product  Regularly busy  Regularly busy
# 4             17     1.0  Low-Range Product  Regularly busy  Regularly busy
# 5              7     9.0  Mid-Range Product  Regularly busy      Least busy
# 6             19     3.0  Low-Range Product  Regularly busy      Least busy
# 7             19     4.4  Low-Range Product  Regularly busy      Least busy
# 8              4    10.3  Mid-Range Product  Regularly busy      Least busy
# 9             19     4.7  Low-Range Product  Regularly busy      Least busy
#
#   busiest_period_of_day
# 0        Average Orders
# 1        Average Orders
# 2        Average Orders
# 3        Average Orders
# 4        Average Orders
# 5        Average Orders
# 6        Average Orders
# 7        Average Orders
# 8        Average Orders
# 9        Average Orders

# %% [markdown]
# ## 04. Finding the Aggregated Mean

# %%
# Find the aggregated mean of the order_number, grouped by department_id
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# ##### The aggregated mean of order_number in the total dataframe is roughly equivalent to the aggregate mean in the subset.
# ##### This tells me that the subset dataframe may be a usable sample population for the entire dataframe.

# %% [markdown]
# ## 05. Creating a Loyalty Flag

# %% [markdown]
# ### Apply the transform() function on the order_number column to get the maximum orders for each user

# %%
# Create a new column (max_order) of the maximum orders for each user
ords_prods_merge['max_order'] = ords_prods_merge.groupby('user_id')['order_number'].transform(np.max)
# Out:
# /var/folders/40/hn3x1h6s6vgb3bv80rtm46q80000gn/T/ipykernel_65110/1192305582.py:2: FutureWarning: The provided callable <function max at 0x104553920> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby('user_id')['order_number'].transform(np.max)

# %%
# Check the output of the max_order column
ords_prods_merge['max_order'].value_counts(dropna = False)
# Out:
# max_order
# 99    1171333
# 8      811843
# 6      811396
# 9      810213
# 7      803979
#        ...
# 97      44949
# 98      44587
# 96      40453
# 2           6
# 1           5
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# ### Assign the Loyalty Flag to each customer based on their maximum order

# %%
# Assign 'Loyal Customer' to customers with a max_order of more than 40
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal Customer'

# %%
# Assign 'Regular Customer' to customers with a max_order of more than 10 and less than or equal to 40
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular Customer'

# %%
# Assign 'New Customer' to customers with a max_order of less than or equal to 10
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
# Check the output of the loyalty_flag column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: count, dtype: int64

# %% [markdown]
# ##### There are more Regular Customers than New or Loyal Customers

# %% [markdown]
# ### Determine the spending habits of the different customer loyalty tiers

# %%
# Find the aggregate mean, minimum, and maximum for the prices variable, grouped by the loyalty_flag groups
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal Customer    7.773575  1.0  25.0
# New Customer      7.801206  1.0  25.0
# Regular Customer  7.798262  1.0  25.0

# %% [markdown]
# ##### New Customers purchase more expensive items on average than Regular Customers, and Regular Customers purchase more expensive items than Loyal Customers
#
# ##### We could look into offering new customer deals that incentivize purchasing expensive items on their first orders, since these customers are already prone to that behavior

# %% [markdown]
# ## 06. Creating a Spending Flag

# %% [markdown]
# ### Apply the transform() function on the prices column to get the average prices of items across all orders for each user

# %%
# Create a new column (average_price_across_orders) of the average price of items purchased by each user
ords_prods_merge['average_price_across_orders'] = ords_prods_merge.groupby('user_id')['prices'].transform(np.mean)
# Out:
# /var/folders/40/hn3x1h6s6vgb3bv80rtm46q80000gn/T/ipykernel_65110/1536517993.py:2: FutureWarning: The provided callable <function mean at 0x104564360> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_price_across_orders'] = ords_prods_merge.groupby('user_id')['prices'].transform(np.mean)

# %%
# Check to see that new column was created successfully
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
# 5   2398795        1             2                  3                  7
# 6   2398795        1             2                  3                  7
# 7   2398795        1             2                  3                  7
# 8   2398795        1             2                  3                  7
# 9   2398795        1             2                  3                  7
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
# 5                    15.0         False         196                  1
# 6                    15.0         False       10258                  2
# 7                    15.0         False       12427                  3
# 8                    15.0         False       13176                  4
# 9                    15.0         False       26088                  5
#
#    reordered  ... aisle_id  department_id  prices        price_label  \
# 0          0  ...       77              7     9.0  Mid-Range Product
# 1          0  ...       91             16    12.5  Mid-Range Product
# 2          0  ...       23             19     4.4  Low-Range Product
# 3          0  ...       23             19     4.7  Low-Range Product
# 4          0  ...       54             17     1.0  Low-Range Product
# 5          1  ...       77              7     9.0  Mid-Range Product
# 6          0  ...      117             19     3.0  Low-Range Product
# 7          1  ...       23             19     4.4  Low-Range Product
# 8          0  ...       24              4    10.3  Mid-Range Product
# 9          1  ...       23             19     4.7  Low-Range Product
#
#       busiest_day    busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy        Average Orders        10
# 1  Regularly busy  Regularly busy        Average Orders        10
# 2  Regularly busy  Regularly busy        Average Orders        10
# 3  Regularly busy  Regularly busy        Average Orders        10
# 4  Regularly busy  Regularly busy        Average Orders        10
# 5  Regularly busy      Least busy        Average Orders        10
# 6  Regularly busy      Least busy        Average Orders        10
# 7  Regularly busy      Least busy        Average Orders        10
# 8  Regularly busy      Least busy        Average Orders        10
# 9  Regularly busy      Least busy        Average Orders        10
#
#    loyalty_flag average_price_across_orders
# 0  New Customer                    6.367797
# 1  New Customer                    6.367797
# 2  New Customer                    6.367797
# 3  New Customer                    6.367797
# 4  New Customer                    6.367797
# 5  New Customer                    6.367797
# 6  New Customer                    6.367797
# 7  New Customer                    6.367797
# 8  New Customer                    6.367797
# 9  New Customer                    6.367797
#
# [10 rows x 21 columns]

# %%
# Check the output of the average_price_across_orders column
ords_prods_merge['average_price_across_orders'].value_counts(dropna = False)
# Out:
# average_price_across_orders
# 8.000000     10492
# 7.500000      9116
# 8.100000      7685
# 7.750000      7435
# 7.400000      7030
#              ...
# 13.133333        3
# 3.300000         3
# 2.700000         3
# 6.400000         3
# 3.533333         3
# Name: count, Length: 128082, dtype: int64

# %% [markdown]
# ### Assign the Spending Flag to each customer based on their average item price

# %%
# Assign 'Low Spender' to customers with a average item price of less than 10
ords_prods_merge.loc[ords_prods_merge['average_price_across_orders'] < 10, 'spending_flag'] = 'Low Spender'

# %%
# Assign 'High Spender' to customers with a average item price of 10 or greater
ords_prods_merge.loc[ords_prods_merge['average_price_across_orders'] >= 10, 'spending_flag'] = 'High Spender'

# %%
# Check the frequency of the spending_flag column
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low Spender     32285131
# High Spender      119728
# Name: count, dtype: int64

# %% [markdown]
# ##### There are many more Low Spenders than there are High Spenders
# ##### The marketing team should target the High Spenders to get them to try other higher priced items, or discount higher priced items to the Low Spenders to get them interested in purchasing these items regularly

# %% [markdown]
# ## 07. Creating a Frequency Flag

# %% [markdown]
# ### Apply the transform() function on the days_since_prior_order column to get the median days since prior order for each user

# %%
# Create a new column (medain_days_since_prior_order) of the regularity of each user's ordering behavior
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby('user_id')['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/40/hn3x1h6s6vgb3bv80rtm46q80000gn/T/ipykernel_65110/3171421059.py:2: FutureWarning: The provided callable <function median at 0x1046d0400> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby('user_id')['days_since_prior_order'].transform(np.median)

# %%
# Check to see that new column was created successfully
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
# 5   2398795        1             2                  3                  7
# 6   2398795        1             2                  3                  7
# 7   2398795        1             2                  3                  7
# 8   2398795        1             2                  3                  7
# 9   2398795        1             2                  3                  7
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
# 5                    15.0         False         196                  1
# 6                    15.0         False       10258                  2
# 7                    15.0         False       12427                  3
# 8                    15.0         False       13176                  4
# 9                    15.0         False       26088                  5
#
#    reordered  ... prices        price_label     busiest_day    busiest_days  \
# 0          0  ...    9.0  Mid-Range Product  Regularly busy  Regularly busy
# 1          0  ...   12.5  Mid-Range Product  Regularly busy  Regularly busy
# 2          0  ...    4.4  Low-Range Product  Regularly busy  Regularly busy
# 3          0  ...    4.7  Low-Range Product  Regularly busy  Regularly busy
# 4          0  ...    1.0  Low-Range Product  Regularly busy  Regularly busy
# 5          1  ...    9.0  Mid-Range Product  Regularly busy      Least busy
# 6          0  ...    3.0  Low-Range Product  Regularly busy      Least busy
# 7          1  ...    4.4  Low-Range Product  Regularly busy      Least busy
# 8          0  ...   10.3  Mid-Range Product  Regularly busy      Least busy
# 9          1  ...    4.7  Low-Range Product  Regularly busy      Least busy
#
#   busiest_period_of_day max_order  loyalty_flag average_price_across_orders  \
# 0        Average Orders        10  New Customer                    6.367797
# 1        Average Orders        10  New Customer                    6.367797
# 2        Average Orders        10  New Customer                    6.367797
# 3        Average Orders        10  New Customer                    6.367797
# 4        Average Orders        10  New Customer                    6.367797
# 5        Average Orders        10  New Customer                    6.367797
# 6        Average Orders        10  New Customer                    6.367797
# 7        Average Orders        10  New Customer                    6.367797
# 8        Average Orders        10  New Customer                    6.367797
# 9        Average Orders        10  New Customer                    6.367797
#
#    spending_flag median_days_since_prior_order
# 0    Low Spender                          20.5
# 1    Low Spender                          20.5
# 2    Low Spender                          20.5
# 3    Low Spender                          20.5
# 4    Low Spender                          20.5
# 5    Low Spender                          20.5
# 6    Low Spender                          20.5
# 7    Low Spender                          20.5
# 8    Low Spender                          20.5
# 9    Low Spender                          20.5
#
# [10 rows x 23 columns]

# %%
# Check the output of the median_days_since_prior_order column
ords_prods_merge['median_days_since_prior_order'].value_counts(dropna = False)
# Out:
# median_days_since_prior_order
# 7.0     5682399
# 6.0     2983604
# 8.0     2713964
# 5.0     2486061
# 4.0     2314289
#          ...
# 26.5       5514
# 29.5       5095
# 1.5        1684
# 0.5         235
# NaN           5
# Name: count, Length: 62, dtype: int64

# %%
# Check why there were 5 NaN values
ords_prods_merge['max_order'].value_counts(dropna = False)
# Out:
# max_order
# 99    1171333
# 8      811843
# 6      811396
# 9      810213
# 7      803979
#        ...
# 97      44949
# 98      44587
# 96      40453
# 2           6
# 1           5
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# ##### Five customers only made one purchase, so their median_days_since_prior_order would be NaN

# %% [markdown]
# ### Assign the Frequency Flag to each customer based on the regularity of their ordering behavior

# %%
# Assign 'Non-Frequent Customer' to customers with a medain days since prior order of more than 20
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'frequency_flag'] = 'Non-Frequent Customer'

# %%
# Assign 'Regular Customer' to customers with a medain days since prior order of more than 10 and less than or equal to 20
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] > 10) & (ords_prods_merge['median_days_since_prior_order'] <= 20), 'frequency_flag'] = 'Regular Customer'

# %%
# Assign 'Frequent Customer' to customers with a medain days since prior order of less than or equal to 10
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
# Check the frequency of the frequency_flag column
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent Customer        21559853
# Regular Customer          7208564
# Non-Frequent Customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %% [markdown]
# ##### There are many more Frequent Customers than Non-Frequent or Regular Customers
# ##### These Frequent Customers would be ideal to target for in-app notifications prompting to repeat their last purchase

# %%
# Check the output of the final dataframe with the all of the new columns added
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
# 5   2398795        1             2                  3                  7
# 6   2398795        1             2                  3                  7
# 7   2398795        1             2                  3                  7
# 8   2398795        1             2                  3                  7
# 9   2398795        1             2                  3                  7
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
# 5                    15.0         False         196                  1
# 6                    15.0         False       10258                  2
# 7                    15.0         False       12427                  3
# 8                    15.0         False       13176                  4
# 9                    15.0         False       26088                  5
#
#    reordered  ...        price_label     busiest_day    busiest_days  \
# 0          0  ...  Mid-Range Product  Regularly busy  Regularly busy
# 1          0  ...  Mid-Range Product  Regularly busy  Regularly busy
# 2          0  ...  Low-Range Product  Regularly busy  Regularly busy
# 3          0  ...  Low-Range Product  Regularly busy  Regularly busy
# 4          0  ...  Low-Range Product  Regularly busy  Regularly busy
# 5          1  ...  Mid-Range Product  Regularly busy      Least busy
# 6          0  ...  Low-Range Product  Regularly busy      Least busy
# 7          1  ...  Low-Range Product  Regularly busy      Least busy
# 8          0  ...  Mid-Range Product  Regularly busy      Least busy
# 9          1  ...  Low-Range Product  Regularly busy      Least busy
#
#    busiest_period_of_day max_order  loyalty_flag average_price_across_orders  \
# 0         Average Orders        10  New Customer                    6.367797
# 1         Average Orders        10  New Customer                    6.367797
# 2         Average Orders        10  New Customer                    6.367797
# 3         Average Orders        10  New Customer                    6.367797
# 4         Average Orders        10  New Customer                    6.367797
# 5         Average Orders        10  New Customer                    6.367797
# 6         Average Orders        10  New Customer                    6.367797
# 7         Average Orders        10  New Customer                    6.367797
# 8         Average Orders        10  New Customer                    6.367797
# 9         Average Orders        10  New Customer                    6.367797
#
#   spending_flag  median_days_since_prior_order         frequency_flag
# 0   Low Spender                           20.5  Non-Frequent Customer
# 1   Low Spender                           20.5  Non-Frequent Customer
# 2   Low Spender                           20.5  Non-Frequent Customer
# 3   Low Spender                           20.5  Non-Frequent Customer
# 4   Low Spender                           20.5  Non-Frequent Customer
# 5   Low Spender                           20.5  Non-Frequent Customer
# 6   Low Spender                           20.5  Non-Frequent Customer
# 7   Low Spender                           20.5  Non-Frequent Customer
# 8   Low Spender                           20.5  Non-Frequent Customer
# 9   Low Spender                           20.5  Non-Frequent Customer
#
# [10 rows x 24 columns]

# %% [markdown]
# ## 08. Exporting the Data

# %%
# Export ords_prods_merge to the Prepared Data folder
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_NewVariables_aggregated.pkl'))

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0
